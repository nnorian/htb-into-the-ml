# %%
import requests 
import zipfile
import io

# %%
import os

extracted_files = os.listdir("/home/nnorian/htb-ai/htb-into-the-ml/skills_assessment_data")
print("extracted files:", extracted_files)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 import os
#       2
# ----> 3 extracted_files = os.listdir("/home/nnorian/htb-ai/htb-into-the-ml/skills_assessment_data")
#       4 print("extracted files:", extracted_files)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nnorian/htb-ai/htb-into-the-ml/skills_assessment_data'

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /home/nnorian/htb-ai/htb-into-the-ml/SPAM-detection
# ['spam_detection_model.joblib', '.ipynb_checkpoints', 'spam_dataset_prap.ipynb', 'sms_spam_collection']
